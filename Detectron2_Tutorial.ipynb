# %% [markdown]
# <a href="https://colab.research.google.com/github/Software-Data/Lumet_FastAPI/blob/main/Detectron2_Tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Detectron2 Beginner's Tutorial
#
# <img src="https://dl.fbaipublicfiles.com/detectron2/Detectron2-Logo-Horz.png" width="500">
#
# Welcome to detectron2! In this tutorial, we will go through some basics usage of detectron2, including the following:
# * Run inference on images or videos, with an existing detectron2 model
# * Train a detectron2 model on a new dataset
#
# You can make a copy of this tutorial to play with it yourself.

# %% [markdown]
# # Install detectron2

# %%
# install dependencies
# !pip install -U torch torchvision cython
# !pip install -U 'git+https://github.com/facebookresearch/fvcore.git' 'git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI'
import torch, torchvision
torch.__version__
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Collecting torch
#   Downloading torch-2.8.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (30 kB)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (0.21.0+cu124)
# Collecting torchvision
#   Downloading torchvision-0.23.0-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (6.1 kB)
# Requirement already satisfied: cython in /usr/local/lib/python3.11/dist-packages (3.0.12)
# Collecting cython
#   Downloading cython-3.1.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (4.7 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.14.1)
# Collecting sympy>=1.13.3 (from torch)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.8.93 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-runtime-cu12==12.8.90 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cuda-cupti-cu12==12.8.90 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cudnn-cu12==9.10.2.21 (from torch)
#   Downloading nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cublas-cu12==12.8.4.1 (from torch)
#   Downloading nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cufft-cu12==11.3.3.83 (from torch)
#   Downloading nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-curand-cu12==10.3.9.90 (from torch)
#   Downloading nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cusolver-cu12==11.7.3.90 (from torch)
#   Downloading nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cusparse-cu12==12.5.8.93 (from torch)
#   Downloading nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-cusparselt-cu12==0.7.1 (from torch)
#   Downloading nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl.metadata (7.0 kB)
# Collecting nvidia-nccl-cu12==2.27.3 (from torch)
#   Downloading nvidia_nccl_cu12-2.27.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (2.0 kB)
# Collecting nvidia-nvtx-cu12==12.8.90 (from torch)
#   Downloading nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvjitlink-cu12==12.8.93 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl.metadata (1.7 kB)
# Collecting nvidia-cufile-cu12==1.13.1.3 (from torch)
#   Downloading nvidia_cufile_cu12-1.13.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.7 kB)
# Collecting triton==3.4.0 (from torch)
#   Downloading triton-3.4.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: setuptools>=40.8.0 in /usr/local/lib/python3.11/dist-packages (from triton==3.4.0->torch) (75.2.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchvision) (2.0.2)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.11/dist-packages (from torchvision) (11.3.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Downloading torch-2.8.0-cp311-cp311-manylinux_2_28_x86_64.whl (888.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 888.1/888.1 MB 1.2 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu12-12.8.4.1-py3-none-manylinux_2_27_x86_64.whl (594.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 594.3/594.3 MB 3.2 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (10.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 97.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (88.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 MB 9.0 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (954 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 954.8/954.8 kB 37.2 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.10.2.21-py3-none-manylinux_2_27_x86_64.whl (706.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 706.8/706.8 MB 2.7 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.3.3.83-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (193.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 193.1/193.1 MB 6.1 MB/s eta 0:00:00
# Downloading nvidia_cufile_cu12-1.13.1.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 55.7 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.9.90-py3-none-manylinux_2_27_x86_64.whl (63.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.6/63.6 MB 13.6 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.7.3.90-py3-none-manylinux_2_27_x86_64.whl (267.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 267.5/267.5 MB 4.4 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.5.8.93-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (288.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 288.2/288.2 MB 2.6 MB/s eta 0:00:00
# Downloading nvidia_cusparselt_cu12-0.7.1-py3-none-manylinux2014_x86_64.whl (287.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 287.2/287.2 MB 4.6 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu12-2.27.3-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (322.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 322.4/322.4 MB 4.9 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.8.93-py3-none-manylinux2010_x86_64.manylinux_2_12_x86_64.whl (39.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 39.3/39.3 MB 22.3 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu12-12.8.90-py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (89 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 8.6 MB/s eta 0:00:00
# Downloading triton-3.4.0-cp311-cp311-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (155.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.5/155.5 MB 6.4 MB/s eta 0:00:00
# Downloading torchvision-0.23.0-cp311-cp311-manylinux_2_28_x86_64.whl (8.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 131.0 MB/s eta 0:00:00
# Downloading cython-3.1.3-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (3.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 111.5 MB/s eta 0:00:00
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 84.4 MB/s eta 0:00:00
# Installing collected packages: nvidia-cusparselt-cu12, triton, sympy, nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufile-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, cython, nvidia-cusparse-cu12, nvidia-cufft-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, torch, torchvision
#   Attempting uninstall: nvidia-cusparselt-cu12
#     Found existing installation: nvidia-cusparselt-cu12 0.6.2
#     Uninstalling nvidia-cusparselt-cu12-0.6.2:
#       Successfully uninstalled nvidia-cusparselt-cu12-0.6.2
#   Attempting uninstall: triton
#     Found existing installation: triton 3.2.0
#     Uninstalling triton-3.2.0:
#       Successfully uninstalled triton-3.2.0
#   Attempting uninstall: sympy
#     Found existing installation: sympy 1.13.1
#     Uninstalling sympy-1.13.1:
#       Successfully uninstalled sympy-1.13.1
#   Attempting uninstall: nvidia-nvtx-cu12
#     Found existing installation: nvidia-nvtx-cu12 12.4.127
#     Uninstalling nvidia-nvtx-cu12-12.4.127:
#       Successfully uninstalled nvidia-nvtx-cu12-12.4.127
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-nccl-cu12
#     Found existing installation: nvidia-nccl-cu12 2.23.4
#     Uninstalling nvidia-nccl-cu12-2.23.4:
#       Successfully uninstalled nvidia-nccl-cu12-2.23.4
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: cython
#     Found existing installation: Cython 3.0.12
#     Uninstalling Cython-3.0.12:
#       Successfully uninstalled Cython-3.0.12
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
#   Attempting uninstall: torch
#     Found existing installation: torch 2.6.0+cu124
#     Uninstalling torch-2.6.0+cu124:
#       Successfully uninstalled torch-2.6.0+cu124
#   Attempting uninstall: torchvision
#     Found existing installation: torchvision 0.21.0+cu124
#     Uninstalling torchvision-0.21.0+cu124:
#       Successfully uninstalled torchvision-0.21.0+cu124
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.6.0+cu124 requires torch==2.6.0, but you have torch 2.8.0 which is incompatible.
# fastai 2.7.19 requires torch<2.7,>=1.10, but you have torch 2.8.0 which is incompatible.
# Successfully installed cython-3.1.3 nvidia-cublas-cu12-12.8.4.1 nvidia-cuda-cupti-cu12-12.8.90 nvidia-cuda-nvrtc-cu12-12.8.93 nvidia-cuda-runtime-cu12-12.8.90 nvidia-cudnn-cu12-9.10.2.21 nvidia-cufft-cu12-11.3.3.83 nvidia-cufile-cu12-1.13.1.3 nvidia-curand-cu12-10.3.9.90 nvidia-cusolver-cu12-11.7.3.90 nvidia-cusparse-cu12-12.5.8.93 nvidia-cusparselt-cu12-0.7.1 nvidia-nccl-cu12-2.27.3 nvidia-nvjitlink-cu12-12.8.93 nvidia-nvtx-cu12-12.8.90 sympy-1.14.0 torch-2.8.0 torchvision-0.23.0 triton-3.4.0
# Collecting git+https://github.com/facebookresearch/fvcore.git
#   Cloning https://github.com/facebookresearch/fvcore.git to /tmp/pip-req-build-mnt0xqo9
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/fvcore.git /tmp/pip-req-build-mnt0xqo9
#   Resolved https://github.com/facebookresearch/fvcore.git to commit 3b2d62f06b22ef743ac394e568e1e87ae12b30a8
#   Preparing metadata (setup.py) ... done
# Collecting git+https://github.com/cocodataset/cocoapi.git#subdirectory=PythonAPI
#   Cloning https://github.com/cocodataset/cocoapi.git to /tmp/pip-req-build-nrk9g1bs
#   Running command git clone --filter=blob:none --quiet https://github.com/cocodataset/cocoapi.git /tmp/pip-req-build-nrk9g1bs
#   Resolved https://github.com/cocodataset/cocoapi.git to commit 8c9bcc3cf640524c4c20a9c40e89cb6a2f2fa0e9
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from fvcore==0.1.6) (2.0.2)
# Collecting yacs>=0.1.6 (from fvcore==0.1.6)
#   Downloading yacs-0.1.8-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from fvcore==0.1.6) (6.0.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from fvcore==0.1.6) (4.67.1)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.11/dist-packages (from fvcore==0.1.6) (3.1.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from fvcore==0.1.6) (11.3.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.11/dist-packages (from fvcore==0.1.6) (0.9.0)
# Collecting iopath>=0.1.7 (from fvcore==0.1.6)
#   Downloading iopath-0.1.10.tar.gz (42 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 kB 2.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: setuptools>=18.0 in /usr/local/lib/python3.11/dist-packages (from pycocotools==2.0) (75.2.0)
# Requirement already satisfied: cython>=0.27.3 in /usr/local/lib/python3.11/dist-packages (from pycocotools==2.0) (3.1.3)
# Requirement already satisfied: matplotlib>=2.1.0 in /usr/local/lib/python3.11/dist-packages (from pycocotools==2.0) (3.10.0)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.11/dist-packages (from iopath>=0.1.7->fvcore==0.1.6) (4.14.1)
# Collecting portalocker (from iopath>=0.1.7->fvcore==0.1.6)
#   Downloading portalocker-3.2.0-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib>=2.1.0->pycocotools==2.0) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib>=2.1.0->pycocotools==2.0) (1.17.0)
# Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Downloading portalocker-3.2.0-py3-none-any.whl (22 kB)
# Building wheels for collected packages: fvcore, pycocotools, iopath
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.6-py3-none-any.whl size=65635 sha256=815eb1a5d6fe533f5469d1d71f9a800dc2a9412c42646d6d087c016a0a2f8627
#   Stored in directory: /tmp/pip-ephem-wheel-cache-gpxnkweu/wheels/cb/7b/f1/170e6ac46b414a6afef30f04f353ef29c6d7b20051358b781a
#   Building wheel for pycocotools (setup.py) ... done
#   Created wheel for pycocotools: filename=pycocotools-2.0-cp311-cp311-linux_x86_64.whl size=404484 sha256=a5ac51c1ffc4ccfe8bc12473269c9504e821040bed909bdafbe3d8f766274693
#   Stored in directory: /tmp/pip-ephem-wheel-cache-gpxnkweu/wheels/6d/69/75/358c50a37672dfda8d74ba3b30ec49fb75d52f7c081886d503
#   Building wheel for iopath (setup.py) ... done
#   Created wheel for iopath: filename=iopath-0.1.10-py3-none-any.whl size=31527 sha256=26541c42329079241bb48225fa0065d325652502bcecc4a8d911eab710530e9a
#   Stored in directory: /root/.cache/pip/wheels/ba/5e/16/6117f8fe7e9c0c161a795e10d94645ebcf301ccbd01f66d8ec
# Successfully built fvcore pycocotools iopath
# Installing collected packages: yacs, portalocker, iopath, pycocotools, fvcore
#   Attempting uninstall: pycocotools
#     Found existing installation: pycocotools 2.0.10
#     Uninstalling pycocotools-2.0.10:
#       Successfully uninstalled pycocotools-2.0.10
# Successfully installed fvcore-0.1.6 iopath-0.1.10 portalocker-3.2.0 pycocotools-2.0 yacs-0.1.8
# '2.8.0+cu128'

# %%
# !git clone https://github.com/facebookresearch/detectron2 detectron2_repo
# !pip install -e detectron2_repo
# Out:
# Cloning into 'detectron2_repo'...
# remote: Enumerating objects: 15908, done.
# remote: Counting objects: 100% (121/121), done.
# remote: Compressing objects: 100% (88/88), done.
# remote: Total 15908 (delta 72), reused 34 (delta 32), pack-reused 15787 (from 2)
# Receiving objects: 100% (15908/15908), 6.46 MiB | 9.38 MiB/s, done.
# Resolving deltas: 100% (11571/11571), done.
# Obtaining file:///content/detectron2_repo
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: Pillow>=7.1 in /usr/local/lib/python3.11/dist-packages (from detectron2==0.6) (11.3.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from detectron2==0.6) (3.10.0)
# Collecting pycocotools>=2.0.2 (from detectron2==0.6)
#   Downloading pycocotools-2.0.10-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (1.3 kB)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.11/dist-packages (from detectron2==0.6) (3.1.0)
# Requirement already satisfied: yacs>=0.1.8 in /usr/local/lib/python3.11/dist-packages (from detectron2==0.6) (0.1.8)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.11/dist-packages (from detectron2==0.6) (0.9.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from detectron2==0.6) (3.1.1)
# Requirement already satisfied: tqdm>4.29.0 in /usr/local/lib/python3.11/dist-packages (from detectron2==0.6) (4.67.1)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.11/dist-packages (from detectron2==0.6) (2.19.0)
# Collecting fvcore<0.1.6,>=0.1.5 (from detectron2==0.6)
#   Downloading fvcore-0.1.5.post20221221.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 2.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting iopath<0.1.10,>=0.1.7 (from detectron2==0.6)
#   Downloading iopath-0.1.9-py3-none-any.whl.metadata (370 bytes)
# Requirement already satisfied: omegaconf<2.4,>=2.1 in /usr/local/lib/python3.11/dist-packages (from detectron2==0.6) (2.3.0)
# Collecting hydra-core>=1.1 (from detectron2==0.6)
#   Downloading hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# Collecting black (from detectron2==0.6)
#   Downloading black-25.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl.metadata (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 5.7 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from detectron2==0.6) (25.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (2.0.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from fvcore<0.1.6,>=0.1.5->detectron2==0.6) (6.0.2)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.11/dist-packages (from hydra-core>=1.1->detectron2==0.6) (4.9.3)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.11/dist-packages (from iopath<0.1.10,>=0.1.7->detectron2==0.6) (3.2.0)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from black->detectron2==0.6) (8.2.1)
# Collecting mypy-extensions>=0.4.3 (from black->detectron2==0.6)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting pathspec>=0.9.0 (from black->detectron2==0.6)
#   Downloading pathspec-0.12.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.11/dist-packages (from black->detectron2==0.6) (4.3.8)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->detectron2==0.6) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->detectron2==0.6) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->detectron2==0.6) (4.59.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->detectron2==0.6) (1.4.9)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->detectron2==0.6) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->detectron2==0.6) (2.9.0.post0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.11/dist-packages (from tensorboard->detectron2==0.6) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.11/dist-packages (from tensorboard->detectron2==0.6) (1.74.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard->detectron2==0.6) (3.8.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.11/dist-packages (from tensorboard->detectron2==0.6) (5.29.5)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard->detectron2==0.6) (75.2.0)
# Requirement already satisfied: six>1.9 in /usr/local/lib/python3.11/dist-packages (from tensorboard->detectron2==0.6) (1.17.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard->detectron2==0.6) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard->detectron2==0.6) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.11/dist-packages (from werkzeug>=1.0.1->tensorboard->detectron2==0.6) (3.0.2)
# Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 11.0 MB/s eta 0:00:00
# Downloading iopath-0.1.9-py3-none-any.whl (27 kB)
# Downloading pycocotools-2.0.10-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (477 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 477.3/477.3 kB 30.0 MB/s eta 0:00:00
# Downloading black-25.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 71.8 MB/s eta 0:00:00
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Downloading pathspec-0.12.1-py3-none-any.whl (31 kB)
# Building wheels for collected packages: fvcore
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61397 sha256=a3835a703081dc7714df0390affcb0cc0556506d03325797f191a0eea1098ad9
#   Stored in directory: /root/.cache/pip/wheels/65/71/95/3b8fde5c65c6e4a806e0867c1651dcc71a1cb2f3430e8f355f
# Successfully built fvcore
# Installing collected packages: pycocotools, pathspec, mypy-extensions, iopath, hydra-core, fvcore, black, detectron2
#   Attempting uninstall: pycocotools
#     Found existing installation: pycocotools 2.0
#     Uninstalling pycocotools-2.0:
#       Successfully uninstalled pycocotools-2.0
#   Attempting uninstall: iopath
#     Found existing installation: iopath 0.1.10
#     Uninstalling iopath-0.1.10:
#       Successfully uninstalled iopath-0.1.10
#   Attempting uninstall: fvcore
#     Found existing installation: fvcore 0.1.6
#     Uninstalling fvcore-0.1.6:
#       Successfully uninstalled fvcore-0.1.6
#   Running setup.py develop for detectron2

# %%
# You may need to restart your runtime prior to this, to let your installation take effect
# Some basic setup
# Setup detectron2 logger
import detectron2
from detectron2.utils.logger import setup_logger
setup_logger()

# import some common libraries
import numpy as np
import cv2
import random
from google.colab.patches import cv2_imshow

# import some common detectron2 utilities
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog

# %% [markdown]
# # Run a pre-trained detectron2 model

# %% [markdown]
# We first download a random image from the COCO dataset:

# %%
# !wget http://images.cocodataset.org/val2017/000000439715.jpg -O input.jpg
im = cv2.imread("./input.jpg")
cv2_imshow(im)
# Out:
# --2025-08-11 08:39:59--  http://images.cocodataset.org/val2017/000000439715.jpg
# Resolving images.cocodataset.org (images.cocodataset.org)... 3.5.21.127, 3.5.1.166, 52.216.33.161, ...
# Connecting to images.cocodataset.org (images.cocodataset.org)|3.5.21.127|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 209222 (204K) [image/jpeg]
# Saving to: ‘input.jpg’
#
# input.jpg           100%[===================>] 204.32K  1.07MB/s    in 0.2s
#
# 2025-08-11 08:39:59 (1.07 MB/s) - ‘input.jpg’ saved [209222/209222]
# <PIL.Image.Image image mode=RGB size=640x480>

# %% [markdown]
# Then, we create a detectron2 config and a detectron2 `DefaultPredictor` to run inference on this image.

# %%
cfg = get_cfg()
cfg.merge_from_file("./detectron2_repo/configs/COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml")
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.5  # set threshold for this model
# Find a model from detectron2's model zoo. You can either use the https://dl.fbaipublicfiles.... url, or use the following shorthand
cfg.MODEL.WEIGHTS = "detectron2://COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x/137849600/model_final_f10217.pkl"
predictor = DefaultPredictor(cfg)
outputs = predictor(im)
# Out:
# [08/11 08:40:03 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from detectron2://COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x/137849600/model_final_f10217.pkl ...
# model_final_f10217.pkl: 178MB [00:00, 260MB/s]
# /usr/local/lib/python3.11/dist-packages/torch/functional.py:554: UserWarning: torch.meshgrid: in an upcoming release, it will be required to pass the indexing argument. (Triggered internally at /pytorch/aten/src/ATen/native/TensorShape.cpp:4322.)
#   return _VF.meshgrid(tensors, **kwargs)  # type: ignore[attr-defined]

# %%
# look at the outputs. See https://detectron2.readthedocs.io/tutorials/models.html#model-output-format for specification
outputs["instances"].pred_classes
outputs["instances"].pred_boxes
# Out:
# Boxes(tensor([[126.6035, 244.8977, 459.8291, 480.0000],
#         [251.1083, 157.8127, 338.9731, 413.6379],
#         [114.8496, 268.6864, 148.2352, 398.8111],
#         [  0.8217, 281.0327,  78.6072, 478.4210],
#         [ 49.3953, 274.1229,  80.1545, 342.9808],
#         [561.2248, 271.5816, 596.2755, 385.2552],
#         [385.9072, 270.3125, 413.7130, 304.0397],
#         [515.9295, 278.3744, 562.2792, 389.3802],
#         [335.2409, 251.9167, 414.7491, 275.9375],
#         [350.9300, 269.2060, 386.0984, 297.9081],
#         [331.6292, 230.9996, 393.2759, 257.2009],
#         [510.7349, 263.2656, 570.9865, 295.9194],
#         [409.0841, 271.8646, 460.5582, 356.8722],
#         [506.8767, 283.3257, 529.9403, 324.0392],
#         [594.5663, 283.4820, 609.0577, 311.4124]], device='cuda:0'))

# %%
# We can use `Visualizer` to draw the predictions on the image.
v = Visualizer(im[:, :, ::-1], MetadataCatalog.get(cfg.DATASETS.TRAIN[0]), scale=1.2)
v = v.draw_instance_predictions(outputs["instances"].to("cpu"))
cv2_imshow(v.get_image()[:, :, ::-1])
# Out:
# <PIL.Image.Image image mode=RGB size=768x576>

# %% [markdown]
# # Train on a custom dataset

# %% [markdown]
# In this section, we show how to train an existing detectron2 model on a custom dataset in a new format.
#
# We use [the balloon segmentation dataset](https://github.com/matterport/Mask_RCNN/tree/master/samples/balloon)
# which only has one class: balloon.
# We'll train a balloon segmentation model from an existing model pre-trained on COCO dataset, available in detectron2's model zoo.
#
# Note that COCO dataset does not have the "balloon" category. We'll be able to recognize this new class in a few minutes.
#
# ## Prepare the dataset

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="3HHs5v93eQmsMpGLituh")
project = rf.workspace("inspeccion-de-calidad").project("car-dent-wxdxn-sftpr")
version = project.version(2)
dataset = version.download("coco-segmentation")
# Out:
# Requirement already satisfied: roboflow in /usr/local/lib/python3.11/dist-packages (1.2.3)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from roboflow) (2025.8.3)
# Requirement already satisfied: idna==3.7 in /usr/local/lib/python3.11/dist-packages (from roboflow) (3.7)
# Requirement already satisfied: cycler in /usr/local/lib/python3.11/dist-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.4.8)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from roboflow) (3.10.0)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.0.2)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in /usr/local/lib/python3.11/dist-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.11/dist-packages (from roboflow) (11.3.0)
# Requirement already satisfied: pi-heif<2 in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.1.0)
# Requirement already satisfied: pillow-avif-plugin<2 in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.5.2)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.9.0.post0)
# Requirement already satisfied: python-dotenv in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.1.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.32.3)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.11/dist-packages (from roboflow) (2.5.0)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.11/dist-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.11/dist-packages (from roboflow) (6.0.2)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.0.0)
# Requirement already satisfied: filetype in /usr/local/lib/python3.11/dist-packages (from roboflow) (1.2.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (1.3.3)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (4.59.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->roboflow) (3.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->roboflow) (3.4.2)
# loading Roboflow workspace...
# loading Roboflow project...

# %% [markdown]
# Register the balloon dataset to detectron2, following the [detectron2 custom dataset tutorial](https://detectron2.readthedocs.io/tutorials/datasets.html).

# %%
# Importa las librerías necesarias para el manejo de datasets
from detectron2.data.datasets import register_coco_instances
from detectron2.data import DatasetCatalog, MetadataCatalog
import os
import cv2 # Para leer las imágenes
from google.colab.patches import cv2_imshow # Para mostrar imágenes en Colab
import random

# --- INICIO DE LA SECCIÓN QUE DEBES AJUSTAR ---

# Ajusta el nombre de la carpeta si es diferente.
# Generalmente Roboflow la nombra como "NombreDelProyecto-Version"
# Puedes ver el nombre exacto en el explorador de archivos a la izquierda de Colab.
dataset_folder_name = "Lumet_FastAPI/dataset"

# --- FIN DE LA SECCIÓN QUE DEBES AJUSTAR ---


# Rutas a las carpetas train y valid de tu dataset
train_dir = os.path.join(dataset_folder_name, "train")
val_dir = os.path.join(dataset_folder_name, "valid")

# Rutas a los archivos de anotaciones JSON
train_json = os.path.join(train_dir, "_annotations.coco.json")
val_json = os.path.join(val_dir, "_annotations.coco.json")

# Registrar tus datasets en Detectron2
register_coco_instances("my_dataset_train", {}, train_json, train_dir)
register_coco_instances("my_dataset_val", {}, val_json, val_dir)

print("¡Datasets registrados exitosamente!")

# --- Verificación Opcional ---
# El siguiente código te permite visualizar una muestra de tus imágenes
# con sus anotaciones para confirmar que todo se cargó correctamente.

print("Mostrando 3 imágenes de muestra del set de entrenamiento:")
train_metadata = MetadataCatalog.get("my_dataset_train")
dataset_dicts = DatasetCatalog.get("my_dataset_train")

from detectron2.utils.visualizer import Visualizer

for d in random.sample(dataset_dicts, 3):
    img = cv2.imread(d["file_name"])
    visualizer = Visualizer(img[:, :, ::-1], metadata=train_metadata, scale=1.2)
    vis = visualizer.draw_dataset_dict(d)
    cv2_imshow(vis.get_image()[:, :, ::-1])
# Out:
# ¡Datasets registrados exitosamente!
# Mostrando 3 imágenes de muestra del set de entrenamiento:
# WARNING:detectron2.data.datasets.coco:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
# <PIL.Image.Image image mode=RGB size=1536x864>
# <PIL.Image.Image image mode=RGB size=1536x1152>
# <PIL.Image.Image image mode=RGB size=1200x902>

# %% [markdown]
# ## Train!
#
# Now, let's fine-tune a coco-pretrained R50-FPN Mask R-CNN model on the balloon dataset. It takes ~6 minutes to train 300 iterations on Colab's K80 GPU, or ~2 minutes on a P100 GPU.

# %%
# Diagnose the error by inspecting the dataset metadata
try:
    train_metadata = MetadataCatalog.get("my_dataset_train")
    print(f"Number of classes in the dataset: {len(train_metadata.thing_classes)}")
    print(f"Configured number of classes: {cfg.MODEL.ROI_HEADS.NUM_CLASSES}")

    if len(train_metadata.thing_classes) != cfg.MODEL.ROI_HEADS.NUM_CLASSES:
        print("Mismatch between dataset classes and configured classes!")
    else:
        print("Number of dataset classes matches configured classes.")

except Exception as e:
    print(f"Error accessing dataset metadata: {e}")
# Out:
# Number of classes in the dataset: 9
# Error accessing dataset metadata: name 'cfg' is not defined

# %%
# --- SCRIPT DE INSPECCIÓN PROFUNDA ---
from detectron2.data import DatasetCatalog
import json

print("--- Iniciando inspección profunda del dataset de entrenamiento ---")

# Asegúrate de que "Lumet_FastAPI-1" es el nombre correcto de tu carpeta
train_json_path = "./train/_annotations.coco.json"

try:
    with open(train_json_path, 'r') as f:
        data = json.load(f)

    image_ids_with_annos = {anno['image_id'] for anno in data['annotations']}
    all_image_ids = {img['id'] for img in data['images']}
    images_without_annos = all_image_ids - image_ids_with_annos

    found_error = False

    # Revisar cada anotación
    for anno in data['annotations']:
        bbox = anno['bbox']  # Formato COCO: [x_min, y_min, width, height]

        # ERROR 1: Bounding box con área cero o negativa
        if bbox[2] <= 0 or bbox[3] <= 0:
            print(f"¡ERROR DE ANOTACIÓN ENCONTRADO!")
            print(f"  - Imagen ID: {anno['image_id']}")
            print(f"  - Anotación ID: {anno['id']}")
            print(f"  - Categoría ID: {anno['category_id']}")
            print(f"  - BBox problemático [x, y, w, h]: {bbox}  <-- ¡El ancho o alto es cero!")
            found_error = True
            break # Detenerse en el primer error encontrado

    if not found_error:
        print("\n¡Buenas noticias! No se encontraron bounding boxes con área cero.")

    if images_without_annos:
        print(f"\nAVISO: Se encontraron {len(images_without_annos)} imágenes sin ninguna anotación.")
        # print(f"  IDs de imágenes sin anotaciones: {list(images_without_annos)[:10]}") # Muestra las primeras 10

except FileNotFoundError:
    print(f"¡ERROR! No se pudo encontrar el archivo en la ruta: {train_json_path}")
    print("Verifica que el nombre de la carpeta 'Lumet_FastAPI-1' sea correcto.")
except Exception as e:
    print(f"Ocurrió un error inesperado al leer el archivo: {e}")
# Out:
# --- Iniciando inspección profunda del dataset de entrenamiento ---
#
# ¡Buenas noticias! No se encontraron bounding boxes con área cero.

# %%
# --- SCRIPT DE DIAGNÓSTICO DEFINITIVO ---
import json
print("--- Iniciando diagnóstico de coordenadas y polígonos ---")

# Asegúrate de que "Lumet_FastAPI-1" es el nombre correcto de tu carpeta
train_json_path = "./train/_annotations.coco.json"
found_error = False

try:
    with open(train_json_path, 'r') as f:
        data = json.load(f)

    # Crear un diccionario para acceder fácilmente a las dimensiones de la imagen
    image_dims = {img['id']: (img['width'], img['height']) for img in data['images']}

    # Revisar cada anotación
    for anno in data['annotations']:
        image_id = anno['image_id']
        img_w, img_h = image_dims[image_id]

        # --- 1. Revisar Coordenadas del Bounding Box ---
        x, y, w, h = anno['bbox']
        if x < 0 or y < 0 or (x + w) > img_w or (y + h) > img_h:
            print(f"¡ERROR DE COORDENADAS DE BOUNDING BOX!")
            print(f"  - Imagen ID: {image_id} (Dimensiones: {img_w}x{img_h})")
            print(f"  - Anotación ID: {anno['id']}")
            print(f"  - BBox [x, y, w, h]: [{x}, {y}, {w}, {h}] está fuera de los límites.")
            found_error = True
            break

        # --- 2. Revisar Polígonos de Segmentación ---
        if 'segmentation' in anno and isinstance(anno['segmentation'], list):
            for seg_poly in anno['segmentation']:
                # Debe ser una lista de números
                if not all(isinstance(p, (int, float)) for p in seg_poly):
                    continue

                # Debe tener un número par de puntos (x, y)
                if len(seg_poly) % 2 != 0:
                    print(f"¡ERROR DE POLÍGONO INVÁLIDO!")
                    print(f"  - Imagen ID: {image_id}")
                    print(f"  - Anotación ID: {anno['id']}")
                    print(f"  - El polígono tiene un número impar de coordenadas.")
                    found_error = True
                    break

                # Comprobar que todos los puntos del polígono están dentro de los límites
                points_x = seg_poly[0::2]
                points_y = seg_poly[1::2]
                if any(px > img_w or px < 0 for px in points_x) or any(py > img_h or py < 0 for py in points_y):
                    print(f"¡ERROR DE COORDENADAS DE POLÍGONO!")
                    print(f"  - Imagen ID: {image_id} (Dimensiones: {img_w}x{img_h})")
                    print(f"  - Anotación ID: {anno['id']}")
                    print(f"  - Un punto en el polígono está fuera de los límites.")
                    found_error = True
                    break
        if found_error:
            break

    if not found_error:
        print("\n--- Diagnóstico Completo ---")
        print("¡Increíble! No se encontraron errores de coordenadas ni de polígonos.")
        print("Esto sugiere que el problema podría ser otro, pero es extremadamente raro.")

except FileNotFoundError:
    print(f"¡ERROR! No se pudo encontrar el archivo en la ruta: {train_json_path}")
except Exception as e:
    print(f"Ocurrió un error inesperado durante el diagnóstico: {e}")
# Out:
# --- Iniciando diagnóstico de coordenadas y polígonos ---
# ¡ERROR DE COORDENADAS DE BOUNDING BOX!
#   - Imagen ID: 166 (Dimensiones: 1280x720)
#   - Anotación ID: 303
#   - BBox [x, y, w, h]: [156, 67, 1124.009, 482.765] está fuera de los límites.

# %%
import json

# Asegúrate de que el nombre de la carpeta sea el correcto
json_path = "./train/_annotations.coco.json"
id_de_imagen_a_buscar = 377

try:
    with open(json_path, 'r') as f:
        data = json.load(f)

    nombre_de_archivo = "No encontrado"
    for img_info in data['images']:
        if img_info['id'] == id_de_imagen_a_buscar:
            nombre_de_archivo = img_info['file_name']
            break

    if nombre_de_archivo != "No encontrado":
        print(f"¡Listo! La imagen que causa el error es:")
        print(f"--> Nombre del archivo: {nombre_de_archivo}")
        print("\nAhora, busca este archivo en Roboflow y corrige la etiqueta que se sale del borde.")
    else:
        print(f"No se pudo encontrar una imagen con el ID {id_de_imagen_a_buscar} en el archivo JSON.")

except FileNotFoundError:
    print(f"Error: No se encontró el archivo en la ruta '{json_path}'. Verifica que el nombre de la carpeta sea correcto.")
# Out:
# ¡Listo! La imagen que causa el error es:
# --> Nombre del archivo: 1_jpg.rf.51a2aed95ede1028c744b5b5df6673d4.jpg
#
# Ahora, busca este archivo en Roboflow y corrige la etiqueta que se sale del borde.

# %%
from detectron2.engine import DefaultTrainer
from detectron2.config import get_cfg
from detectron2 import model_zoo
import os
os.environ['CUDA_LAUNCH_BLOCKING'] = "1"

cfg = get_cfg()
cfg.merge_from_file(model_zoo.get_config_file("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml"))

cfg.DATASETS.TRAIN = ("my_dataset_train",)
cfg.DATASETS.TEST = ("my_dataset_val",)
cfg.DATALOADER.NUM_WORKERS = 2
cfg.MODEL.WEIGHTS = model_zoo.get_checkpoint_url("COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x.yaml")
cfg.SOLVER.IMS_PER_BATCH = 2
cfg.SOLVER.BASE_LR = 0.00025
cfg.SOLVER.MAX_ITER = 35000 # Para 9 clases, es bueno darle más tiempo para aprender.

# --- ¡LA CORRECCIÓN DEFINITIVA ESTÁ AQUÍ! ---
# Tu dataset tiene 9 categorías en total (con IDs del 0 al 8).
cfg.MODEL.ROI_HEADS.NUM_CLASSES = 9
# ---------------------------------------------

os.makedirs(cfg.OUTPUT_DIR, exist_ok=True)
trainer = DefaultTrainer(cfg)
trainer.resume_or_load(resume=False)

print("¡Configuración final lista! El número de clases (9) ahora coincide con el dataset.")
# Out:
# [08/11 09:25:22 d2.engine.defaults]: Model:
# GeneralizedRCNN(
#   (backbone): FPN(
#     (fpn_lateral2): Conv2d(256, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral3): Conv2d(512, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output3): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral4): Conv2d(1024, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output4): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (fpn_lateral5): Conv2d(2048, 256, kernel_size=(1, 1), stride=(1, 1))
#     (fpn_output5): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (top_block): LastLevelMaxPool()
#     (bottom_up): ResNet(
#       (stem): BasicStem(
#         (conv1): Conv2d(
#           3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False
#           (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#         )
#       )
#       (res2): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             64, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             256, 64, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=64, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             64, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#         )
#       )
#       (res3): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             256, 128, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             512, 128, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=128, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             128, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#         )
#       )
#       (res4): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             512, 1024, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             512, 256, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (3): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (4): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#         (5): BottleneckBlock(
#           (conv1): Conv2d(
#             1024, 256, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=256, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             256, 1024, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=1024, eps=1e-05)
#           )
#         )
#       )
#       (res5): Sequential(
#         (0): BottleneckBlock(
#           (shortcut): Conv2d(
#             1024, 2048, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#           (conv1): Conv2d(
#             1024, 512, kernel_size=(1, 1), stride=(2, 2), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (1): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#         (2): BottleneckBlock(
#           (conv1): Conv2d(
#             2048, 512, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv2): Conv2d(
#             512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=512, eps=1e-05)
#           )
#           (conv3): Conv2d(
#             512, 2048, kernel_size=(1, 1), stride=(1, 1), bias=False
#             (norm): FrozenBatchNorm2d(num_features=2048, eps=1e-05)
#           )
#         )
#       )
#     )
#   )
#   (proposal_generator): RPN(
#     (rpn_head): StandardRPNHead(
#       (conv): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (objectness_logits): Conv2d(256, 3, kernel_size=(1, 1), stride=(1, 1))
#       (anchor_deltas): Conv2d(256, 12, kernel_size=(1, 1), stride=(1, 1))
#     )
#     (anchor_generator): DefaultAnchorGenerator(
#       (cell_anchors): BufferList()
#     )
#   )
#   (roi_heads): StandardROIHeads(
#     (box_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(7, 7), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(7, 7), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(7, 7), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(7, 7), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (box_head): FastRCNNConvFCHead(
#       (flatten): Flatten(start_dim=1, end_dim=-1)
#       (fc1): Linear(in_features=12544, out_features=1024, bias=True)
#       (fc_relu1): ReLU()
#       (fc2): Linear(in_features=1024, out_features=1024, bias=True)
#       (fc_relu2): ReLU()
#     )
#     (box_predictor): FastRCNNOutputLayers(
#       (cls_score): Linear(in_features=1024, out_features=10, bias=True)
#       (bbox_pred): Linear(in_features=1024, out_features=36, bias=True)
#     )
#     (mask_pooler): ROIPooler(
#       (level_poolers): ModuleList(
#         (0): ROIAlign(output_size=(14, 14), spatial_scale=0.25, sampling_ratio=0, aligned=True)
#         (1): ROIAlign(output_size=(14, 14), spatial_scale=0.125, sampling_ratio=0, aligned=True)
#         (2): ROIAlign(output_size=(14, 14), spatial_scale=0.0625, sampling_ratio=0, aligned=True)
#         (3): ROIAlign(output_size=(14, 14), spatial_scale=0.03125, sampling_ratio=0, aligned=True)
#       )
#     )
#     (mask_head): MaskRCNNConvUpsampleHead(
#       (mask_fcn1): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn2): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn3): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (mask_fcn4): Conv2d(
#         256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1)
#         (activation): ReLU()
#       )
#       (deconv): ConvTranspose2d(256, 256, kernel_size=(2, 2), stride=(2, 2))
#       (deconv_relu): ReLU()
#       (predictor): Conv2d(256, 9, kernel_size=(1, 1), stride=(1, 1))
#     )
#   )
# )
# WARNING [08/11 09:25:23 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [08/11 09:25:23 d2.data.datasets.coco]: Loaded 6621 images in COCO format from Lumet_FastAPI/dataset/train/_annotations.coco.json
# [08/11 09:25:23 d2.data.build]: Removed 0 images with no usable annotations. 6621 images left.
# [08/11 09:25:23 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in training: [ResizeShortestEdge(short_edge_length=(640, 672, 704, 736, 768, 800), max_size=1333, sample_style='choice'), RandomFlip()]
# [08/11 09:25:23 d2.data.build]: Using training sampler TrainingSampler
# [08/11 09:25:23 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [08/11 09:25:23 d2.data.common]: Serializing 6621 elements to byte tensors and concatenating them all ...
# [08/11 09:25:23 d2.data.common]: Serialized dataset takes 10.44 MiB
# [08/11 09:25:23 d2.data.build]: Making batched data loader with batch_size=2
# WARNING [08/11 09:25:23 d2.solver.build]: SOLVER.STEPS contains values larger than SOLVER.MAX_ITER. These values will be ignored.
# [08/11 09:25:23 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from https://dl.fbaipublicfiles.com/detectron2/COCO-InstanceSegmentation/mask_rcnn_R_50_FPN_3x/137849600/model_final_f10217.pkl ...
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.cls_score.weight' to the model due to incompatible shapes: (81, 1024) in the checkpoint but (10, 1024) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.cls_score.bias' to the model due to incompatible shapes: (81,) in the checkpoint but (10,) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.bbox_pred.weight' to the model due to incompatible shapes: (320, 1024) in the checkpoint but (36, 1024) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.box_predictor.bbox_pred.bias' to the model due to incompatible shapes: (320,) in the checkpoint but (36,) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.mask_head.predictor.weight' to the model due to incompatible shapes: (80, 256, 1, 1) in the checkpoint but (9, 256, 1, 1) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Skip loading parameter 'roi_heads.mask_head.predictor.bias' to the model due to incompatible shapes: (80,) in the checkpoint but (9,) in the model! You might want to double check if this is expected.
# WARNING:fvcore.common.checkpoint:Some model parameters or buffers are not found in the checkpoint:
# roi_heads.box_predictor.bbox_pred.{bias, weight}
# roi_heads.box_predictor.cls_score.{bias, weight}
# roi_heads.mask_head.predictor.{bias, weight}
# ¡Configuración final lista! El número de clases (9) ahora coincide con el dataset.
# [08/11 09:25:23 d2.engine.train_loop]: Starting training from iteration 0
# [08/11 09:25:35 d2.utils.events]:  eta: 0:14:17  iter: 19  total_loss: 3.133  loss_cls: 2.014  loss_box_reg: 0.04209  loss_mask: 0.6928  loss_rpn_cls: 0.3646  loss_rpn_loc: 0.04369    time: 0.5715  last_time: 0.6303  data_time: 0.0297  last_data_time: 0.0056   lr: 4.9953e-06  max_mem: 2798M
# [08/11 09:25:47 d2.utils.events]:  eta: 0:14:46  iter: 39  total_loss: 3.22  loss_cls: 1.804  loss_box_reg: 0.05852  loss_mask: 0.692  loss_rpn_cls: 0.7011  loss_rpn_loc: 0.09536    time: 0.5919  last_time: 0.6255  data_time: 0.0166  last_data_time: 0.0122   lr: 9.9902e-06  max_mem: 2798M
# [08/11 09:26:00 d2.utils.events]:  eta: 0:14:51  iter: 59  total_loss: 2.568  loss_cls: 1.379  loss_box_reg: 0.07924  loss_mask: 0.6903  loss_rpn_cls: 0.3471  loss_rpn_loc: 0.0558    time: 0.6087  last_time: 0.7345  data_time: 0.0121  last_data_time: 0.0061   lr: 1.4985e-05  max_mem: 2798M
# [08/11 09:26:13 d2.utils.events]:  eta: 0:14:46  iter: 79  total_loss: 2.04  loss_cls: 0.9034  loss_box_reg: 0.06927  loss_mask: 0.6875  loss_rpn_cls: 0.2989  loss_rpn_loc: 0.03875    time: 0.6111  last_time: 0.7652  data_time: 0.0090  last_data_time: 0.0220   lr: 1.998e-05  max_mem: 2798M
# [08/11 09:26:25 d2.utils.events]:  eta: 0:14:35  iter: 99  total_loss: 1.567  loss_cls: 0.5091  loss_box_reg: 0.08406  loss_mask: 0.6755  loss_rpn_cls: 0.1795  loss_rpn_loc: 0.04168    time: 0.6134  last_time: 0.6494  data_time: 0.0086  last_data_time: 0.0143   lr: 2.4975e-05  max_mem: 2798M
# [08/11 09:26:38 d2.utils.events]:  eta: 0:14:26  iter: 119  total_loss: 1.291  loss_cls: 0.3024  loss_box_reg: 0.09451  loss_mask: 0.6727  loss_rpn_cls: 0.1572  loss_rpn_loc: 0.03436    time: 0.6225  last_time: 0.6826  data_time: 0.0103  last_data_time: 0.0128   lr: 2.997e-05  max_mem: 2798M
# [08/11 09:26:51 d2.utils.events]:  eta: 0:14:11  iter: 139  total_loss: 1.112  loss_cls: 0.2189  loss_box_reg: 0.0728  loss_mask: 0.6667  loss_rpn_cls: 0.1199  loss_rpn_loc: 0.0513    time: 0.6193  last_time: 0.7682  data_time: 0.0101  last_data_time: 0.0266   lr: 3.4965e-05  max_mem: 2798M
# [08/11 09:27:02 d2.utils.events]:  eta: 0:13:53  iter: 159  total_loss: 0.9758  loss_cls: 0.1537  loss_box_reg: 0.07287  loss_mask: 0.666  loss_rpn_cls: 0.02604  loss_rpn_loc: 0.03687    time: 0.6163  last_time: 0.7075  data_time: 0.0093  last_data_time: 0.0173   lr: 3.996e-05  max_mem: 2798M
# [08/11 09:27:14 d2.utils.events]:  eta: 0:13:31  iter: 179  total_loss: 0.9917  loss_cls: 0.1494  loss_box_reg: 0.07903  loss_mask: 0.6628  loss_rpn_cls: 0.0261  loss_rpn_loc: 0.0289    time: 0.6119  last_time: 0.5670  data_time: 0.0099  last_data_time: 0.0036   lr: 4.4955e-05  max_mem: 2798M
# [08/11 09:27:26 d2.utils.events]:  eta: 0:13:15  iter: 199  total_loss: 0.9588  loss_cls: 0.1201  loss_box_reg: 0.07029  loss_mask: 0.6429  loss_rpn_cls: 0.03422  loss_rpn_loc: 0.01763    time: 0.6098  last_time: 0.6354  data_time: 0.0107  last_data_time: 0.0057   lr: 4.995e-05  max_mem: 2798M
# [08/11 09:27:38 d2.utils.events]:  eta: 0:13:02  iter: 219  total_loss: 0.8918  loss_cls: 0.1172  loss_box_reg: 0.0613  loss_mask: 0.6374  loss_rpn_cls: 0.02481  loss_rpn_loc: 0.01585    time: 0.6085  last_time: 0.6103  data_time: 0.0092  last_data_time: 0.0056   lr: 5.4945e-05  max_mem: 2798M
# [08/11 09:27:49 d2.utils.events]:  eta: 0:12:48  iter: 239  total_loss: 0.8767  loss_cls: 0.08327  loss_box_reg: 0.03179  loss_mask: 0.6636  loss_rpn_cls: 0.02763  loss_rpn_loc: 0.01524    time: 0.6059  last_time: 0.5580  data_time: 0.0146  last_data_time: 0.0383   lr: 5.994e-05  max_mem: 2798M
# [08/11 09:28:01 d2.utils.events]:  eta: 0:12:35  iter: 259  total_loss: 0.9037  loss_cls: 0.08793  loss_box_reg: 0.05386  loss_mask: 0.6299  loss_rpn_cls: 0.03687  loss_rpn_loc: 0.03187    time: 0.6035  last_time: 0.6155  data_time: 0.0088  last_data_time: 0.0055   lr: 6.4935e-05  max_mem: 2798M
# [08/11 09:28:13 d2.utils.events]:  eta: 0:12:22  iter: 279  total_loss: 0.9757  loss_cls: 0.116  loss_box_reg: 0.06644  loss_mask: 0.6283  loss_rpn_cls: 0.04669  loss_rpn_loc: 0.05926    time: 0.6027  last_time: 0.6556  data_time: 0.0094  last_data_time: 0.0169   lr: 6.993e-05  max_mem: 2798M
# [08/11 09:28:25 d2.utils.events]:  eta: 0:12:11  iter: 299  total_loss: 0.9487  loss_cls: 0.1115  loss_box_reg: 0.06348  loss_mask: 0.608  loss_rpn_cls: 0.06043  loss_rpn_loc: 0.04343    time: 0.6024  last_time: 0.4514  data_time: 0.0145  last_data_time: 0.0054   lr: 7.4925e-05  max_mem: 2798M
# [08/11 09:28:37 d2.utils.events]:  eta: 0:12:00  iter: 319  total_loss: 0.8247  loss_cls: 0.08565  loss_box_reg: 0.05853  loss_mask: 0.5831  loss_rpn_cls: 0.05791  loss_rpn_loc: 0.03137    time: 0.6031  last_time: 0.5875  data_time: 0.0114  last_data_time: 0.0146   lr: 7.992e-05  max_mem: 2798M
# [08/11 09:28:49 d2.utils.events]:  eta: 0:11:47  iter: 339  total_loss: 0.8622  loss_cls: 0.09595  loss_box_reg: 0.07201  loss_mask: 0.5723  loss_rpn_cls: 0.04617  loss_rpn_loc: 0.0372    time: 0.6017  last_time: 0.6149  data_time: 0.0106  last_data_time: 0.0056   lr: 8.4915e-05  max_mem: 2798M
# [08/11 09:29:01 d2.utils.events]:  eta: 0:11:35  iter: 359  total_loss: 0.82  loss_cls: 0.08714  loss_box_reg: 0.07511  loss_mask: 0.5563  loss_rpn_cls: 0.03131  loss_rpn_loc: 0.03507    time: 0.6027  last_time: 0.6372  data_time: 0.0094  last_data_time: 0.0142   lr: 8.991e-05  max_mem: 2798M
# [08/11 09:29:13 d2.utils.events]:  eta: 0:11:24  iter: 379  total_loss: 0.859  loss_cls: 0.09902  loss_box_reg: 0.05696  loss_mask: 0.5267  loss_rpn_cls: 0.04595  loss_rpn_loc: 0.0442    time: 0.6036  last_time: 0.5307  data_time: 0.0132  last_data_time: 0.0037   lr: 9.4905e-05  max_mem: 2798M
# [08/11 09:29:25 d2.utils.events]:  eta: 0:11:12  iter: 399  total_loss: 0.8511  loss_cls: 0.1091  loss_box_reg: 0.07241  loss_mask: 0.5212  loss_rpn_cls: 0.0545  loss_rpn_loc: 0.03295    time: 0.6033  last_time: 0.6767  data_time: 0.0120  last_data_time: 0.0080   lr: 9.99e-05  max_mem: 2798M
# [08/11 09:29:37 d2.utils.events]:  eta: 0:10:59  iter: 419  total_loss: 0.7983  loss_cls: 0.09931  loss_box_reg: 0.08961  loss_mask: 0.4855  loss_rpn_cls: 0.04739  loss_rpn_loc: 0.04186    time: 0.6027  last_time: 0.5810  data_time: 0.0108  last_data_time: 0.0143   lr: 0.0001049  max_mem: 2798M
# [08/11 09:29:49 d2.utils.events]:  eta: 0:10:47  iter: 439  total_loss: 0.7969  loss_cls: 0.09142  loss_box_reg: 0.08689  loss_mask: 0.5047  loss_rpn_cls: 0.04119  loss_rpn_loc: 0.03826    time: 0.6023  last_time: 0.6089  data_time: 0.0115  last_data_time: 0.0032   lr: 0.00010989  max_mem: 2798M
# [08/11 09:30:01 d2.utils.events]:  eta: 0:10:35  iter: 459  total_loss: 0.7036  loss_cls: 0.09626  loss_box_reg: 0.08827  loss_mask: 0.4312  loss_rpn_cls: 0.02299  loss_rpn_loc: 0.01816    time: 0.6023  last_time: 0.5581  data_time: 0.0108  last_data_time: 0.0056   lr: 0.00011489  max_mem: 2798M
# [08/11 09:30:13 d2.utils.events]:  eta: 0:10:23  iter: 479  total_loss: 0.7589  loss_cls: 0.09945  loss_box_reg: 0.07817  loss_mask: 0.4782  loss_rpn_cls: 0.02737  loss_rpn_loc: 0.02773    time: 0.6021  last_time: 0.5993  data_time: 0.0129  last_data_time: 0.0061   lr: 0.00011988  max_mem: 2798M
# [08/11 09:30:25 d2.utils.events]:  eta: 0:10:10  iter: 499  total_loss: 0.7762  loss_cls: 0.116  loss_box_reg: 0.102  loss_mask: 0.3822  loss_rpn_cls: 0.02403  loss_rpn_loc: 0.05057    time: 0.6024  last_time: 0.5894  data_time: 0.0137  last_data_time: 0.0130   lr: 0.00012488  max_mem: 2798M
# [08/11 09:30:38 d2.utils.events]:  eta: 0:09:59  iter: 519  total_loss: 0.6835  loss_cls: 0.09167  loss_box_reg: 0.08968  loss_mask: 0.4345  loss_rpn_cls: 0.02563  loss_rpn_loc: 0.02667    time: 0.6034  last_time: 0.6181  data_time: 0.0134  last_data_time: 0.0109   lr: 0.00012987  max_mem: 2798M
# [08/11 09:30:50 d2.utils.events]:  eta: 0:09:47  iter: 539  total_loss: 0.7088  loss_cls: 0.09222  loss_box_reg: 0.1005  loss_mask: 0.4071  loss_rpn_cls: 0.02967  loss_rpn_loc: 0.01877    time: 0.6029  last_time: 0.5143  data_time: 0.0125  last_data_time: 0.0137   lr: 0.00013487  max_mem: 2799M
# [08/11 09:31:01 d2.utils.events]:  eta: 0:09:35  iter: 559  total_loss: 0.7104  loss_cls: 0.08123  loss_box_reg: 0.08072  loss_mask: 0.3933  loss_rpn_cls: 0.04065  loss_rpn_loc: 0.01823    time: 0.6023  last_time: 0.5568  data_time: 0.0145  last_data_time: 0.0139   lr: 0.00013986  max_mem: 2799M
# [08/11 09:31:13 d2.utils.events]:  eta: 0:09:22  iter: 579  total_loss: 0.7011  loss_cls: 0.08118  loss_box_reg: 0.09818  loss_mask: 0.4045  loss_rpn_cls: 0.02123  loss_rpn_loc: 0.03341    time: 0.6019  last_time: 0.3532  data_time: 0.0113  last_data_time: 0.0052   lr: 0.00014486  max_mem: 2799M
# [08/11 09:31:26 d2.utils.events]:  eta: 0:09:10  iter: 599  total_loss: 0.6685  loss_cls: 0.06938  loss_box_reg: 0.09728  loss_mask: 0.3574  loss_rpn_cls: 0.02688  loss_rpn_loc: 0.04247    time: 0.6026  last_time: 0.4975  data_time: 0.0119  last_data_time: 0.0128   lr: 0.00014985  max_mem: 2800M
# [08/11 09:31:38 d2.utils.events]:  eta: 0:08:58  iter: 619  total_loss: 0.6136  loss_cls: 0.0712  loss_box_reg: 0.1082  loss_mask: 0.36  loss_rpn_cls: 0.02405  loss_rpn_loc: 0.0207    time: 0.6029  last_time: 0.5937  data_time: 0.0086  last_data_time: 0.0057   lr: 0.00015485  max_mem: 2800M
# [08/11 09:31:50 d2.utils.events]:  eta: 0:08:47  iter: 639  total_loss: 0.7544  loss_cls: 0.09463  loss_box_reg: 0.08642  loss_mask: 0.4827  loss_rpn_cls: 0.03325  loss_rpn_loc: 0.06653    time: 0.6034  last_time: 0.5129  data_time: 0.0105  last_data_time: 0.0046   lr: 0.00015984  max_mem: 2800M
# [08/11 09:32:02 d2.utils.events]:  eta: 0:08:34  iter: 659  total_loss: 0.6091  loss_cls: 0.06505  loss_box_reg: 0.06293  loss_mask: 0.4208  loss_rpn_cls: 0.03402  loss_rpn_loc: 0.01713    time: 0.6027  last_time: 0.6112  data_time: 0.0080  last_data_time: 0.0054   lr: 0.00016484  max_mem: 2800M
# [08/11 09:32:14 d2.utils.events]:  eta: 0:08:22  iter: 679  total_loss: 0.6602  loss_cls: 0.08943  loss_box_reg: 0.08388  loss_mask: 0.3528  loss_rpn_cls: 0.02395  loss_rpn_loc: 0.02665    time: 0.6028  last_time: 0.6910  data_time: 0.0129  last_data_time: 0.0418   lr: 0.00016983  max_mem: 2800M
# [08/11 09:32:26 d2.utils.events]:  eta: 0:08:10  iter: 699  total_loss: 0.6399  loss_cls: 0.0764  loss_box_reg: 0.09843  loss_mask: 0.382  loss_rpn_cls: 0.02443  loss_rpn_loc: 0.03476    time: 0.6028  last_time: 0.6261  data_time: 0.0106  last_data_time: 0.0150   lr: 0.00017483  max_mem: 2800M
# [08/11 09:32:38 d2.utils.events]:  eta: 0:07:57  iter: 719  total_loss: 0.7259  loss_cls: 0.08328  loss_box_reg: 0.09646  loss_mask: 0.4218  loss_rpn_cls: 0.01759  loss_rpn_loc: 0.01993    time: 0.6031  last_time: 0.5358  data_time: 0.0093  last_data_time: 0.0052   lr: 0.00017982  max_mem: 2800M
# [08/11 09:32:50 d2.utils.events]:  eta: 0:07:45  iter: 739  total_loss: 0.6404  loss_cls: 0.07217  loss_box_reg: 0.08107  loss_mask: 0.4072  loss_rpn_cls: 0.01396  loss_rpn_loc: 0.01014    time: 0.6026  last_time: 0.5312  data_time: 0.0134  last_data_time: 0.0123   lr: 0.00018482  max_mem: 2800M
# [08/11 09:33:02 d2.utils.events]:  eta: 0:07:33  iter: 759  total_loss: 0.6641  loss_cls: 0.05614  loss_box_reg: 0.05751  loss_mask: 0.3376  loss_rpn_cls: 0.02894  loss_rpn_loc: 0.02116    time: 0.6026  last_time: 0.3958  data_time: 0.0100  last_data_time: 0.0119   lr: 0.00018981  max_mem: 2800M
# [08/11 09:33:15 d2.utils.events]:  eta: 0:07:21  iter: 779  total_loss: 0.6905  loss_cls: 0.0782  loss_box_reg: 0.09358  loss_mask: 0.3833  loss_rpn_cls: 0.036  loss_rpn_loc: 0.03919    time: 0.6031  last_time: 0.5952  data_time: 0.0142  last_data_time: 0.0152   lr: 0.00019481  max_mem: 2800M
# [08/11 09:33:27 d2.utils.events]:  eta: 0:07:09  iter: 799  total_loss: 0.543  loss_cls: 0.05857  loss_box_reg: 0.07371  loss_mask: 0.3413  loss_rpn_cls: 0.02738  loss_rpn_loc: 0.02386    time: 0.6032  last_time: 0.5838  data_time: 0.0114  last_data_time: 0.0060   lr: 0.0001998  max_mem: 2800M
# [08/11 09:33:39 d2.utils.events]:  eta: 0:06:57  iter: 819  total_loss: 0.5508  loss_cls: 0.07223  loss_box_reg: 0.0887  loss_mask: 0.312  loss_rpn_cls: 0.02786  loss_rpn_loc: 0.02417    time: 0.6035  last_time: 0.6189  data_time: 0.0132  last_data_time: 0.0061   lr: 0.0002048  max_mem: 2801M
# [08/11 09:33:51 d2.utils.events]:  eta: 0:06:44  iter: 839  total_loss: 0.5761  loss_cls: 0.06636  loss_box_reg: 0.08696  loss_mask: 0.3413  loss_rpn_cls: 0.02925  loss_rpn_loc: 0.03343    time: 0.6038  last_time: 0.6340  data_time: 0.0118  last_data_time: 0.0159   lr: 0.00020979  max_mem: 2801M
# [08/11 09:34:03 d2.utils.events]:  eta: 0:06:32  iter: 859  total_loss: 0.5337  loss_cls: 0.05045  loss_box_reg: 0.08074  loss_mask: 0.341  loss_rpn_cls: 0.02156  loss_rpn_loc: 0.02277    time: 0.6038  last_time: 0.4903  data_time: 0.0101  last_data_time: 0.0124   lr: 0.00021479  max_mem: 2801M
# [08/11 09:34:15 d2.utils.events]:  eta: 0:06:19  iter: 879  total_loss: 0.575  loss_cls: 0.0648  loss_box_reg: 0.0721  loss_mask: 0.3759  loss_rpn_cls: 0.03544  loss_rpn_loc: 0.02033    time: 0.6037  last_time: 0.6025  data_time: 0.0119  last_data_time: 0.0179   lr: 0.00021978  max_mem: 2801M
# [08/11 09:34:28 d2.utils.events]:  eta: 0:06:07  iter: 899  total_loss: 0.5602  loss_cls: 0.05745  loss_box_reg: 0.1094  loss_mask: 0.3056  loss_rpn_cls: 0.02001  loss_rpn_loc: 0.02755    time: 0.6043  last_time: 0.5553  data_time: 0.0123  last_data_time: 0.0050   lr: 0.00022478  max_mem: 2801M
# [08/11 09:34:41 d2.utils.events]:  eta: 0:05:55  iter: 919  total_loss: 0.4912  loss_cls: 0.05372  loss_box_reg: 0.08625  loss_mask: 0.2824  loss_rpn_cls: 0.01408  loss_rpn_loc: 0.02877    time: 0.6048  last_time: 0.5998  data_time: 0.0107  last_data_time: 0.0060   lr: 0.00022977  max_mem: 2801M
# [08/11 09:34:53 d2.utils.events]:  eta: 0:05:43  iter: 939  total_loss: 0.5525  loss_cls: 0.05817  loss_box_reg: 0.06217  loss_mask: 0.3453  loss_rpn_cls: 0.01295  loss_rpn_loc: 0.02544    time: 0.6054  last_time: 0.5928  data_time: 0.0130  last_data_time: 0.0061   lr: 0.00023477  max_mem: 2801M
# [08/11 09:35:06 d2.utils.events]:  eta: 0:05:31  iter: 959  total_loss: 0.6288  loss_cls: 0.04351  loss_box_reg: 0.07817  loss_mask: 0.3392  loss_rpn_cls: 0.02794  loss_rpn_loc: 0.02702    time: 0.6055  last_time: 0.5596  data_time: 0.0114  last_data_time: 0.0056   lr: 0.00023976  max_mem: 2801M
# [08/11 09:35:18 d2.utils.events]:  eta: 0:05:19  iter: 979  total_loss: 0.6389  loss_cls: 0.06154  loss_box_reg: 0.07243  loss_mask: 0.4063  loss_rpn_cls: 0.04003  loss_rpn_loc: 0.05005    time: 0.6055  last_time: 0.6273  data_time: 0.0112  last_data_time: 0.0066   lr: 0.00024476  max_mem: 2801M
# [08/11 09:35:30 d2.utils.events]:  eta: 0:05:07  iter: 999  total_loss: 0.5557  loss_cls: 0.06385  loss_box_reg: 0.07961  loss_mask: 0.3102  loss_rpn_cls: 0.02907  loss_rpn_loc: 0.03563    time: 0.6057  last_time: 0.6551  data_time: 0.0080  last_data_time: 0.0125   lr: 0.00024975  max_mem: 2801M
# [08/11 09:35:42 d2.utils.events]:  eta: 0:04:55  iter: 1019  total_loss: 0.5035  loss_cls: 0.05361  loss_box_reg: 0.04834  loss_mask: 0.3375  loss_rpn_cls: 0.02461  loss_rpn_loc: 0.01591    time: 0.6060  last_time: 0.5935  data_time: 0.0114  last_data_time: 0.0058   lr: 0.00025  max_mem: 2801M
# [08/11 09:35:55 d2.utils.events]:  eta: 0:04:42  iter: 1039  total_loss: 0.5548  loss_cls: 0.04409  loss_box_reg: 0.05559  loss_mask: 0.3379  loss_rpn_cls: 0.04077  loss_rpn_loc: 0.02813    time: 0.6061  last_time: 0.5298  data_time: 0.0097  last_data_time: 0.0075   lr: 0.00025  max_mem: 2801M
# [08/11 09:36:07 d2.utils.events]:  eta: 0:04:30  iter: 1059  total_loss: 0.4566  loss_cls: 0.03971  loss_box_reg: 0.05924  loss_mask: 0.2695  loss_rpn_cls: 0.02342  loss_rpn_loc: 0.02315    time: 0.6064  last_time: 0.4058  data_time: 0.0117  last_data_time: 0.0056   lr: 0.00025  max_mem: 2801M
# [08/11 09:36:20 d2.utils.events]:  eta: 0:04:18  iter: 1079  total_loss: 0.5177  loss_cls: 0.04351  loss_box_reg: 0.07745  loss_mask: 0.3449  loss_rpn_cls: 0.01837  loss_rpn_loc: 0.03406    time: 0.6072  last_time: 0.6539  data_time: 0.0146  last_data_time: 0.0118   lr: 0.00025  max_mem: 2801M
# [08/11 09:36:32 d2.utils.events]:  eta: 0:04:05  iter: 1099  total_loss: 0.5078  loss_cls: 0.04678  loss_box_reg: 0.06335  loss_mask: 0.296  loss_rpn_cls: 0.01277  loss_rpn_loc: 0.02527    time: 0.6073  last_time: 0.6690  data_time: 0.0106  last_data_time: 0.0085   lr: 0.00025  max_mem: 2801M
# [08/11 09:36:45 d2.utils.events]:  eta: 0:03:53  iter: 1119  total_loss: 0.5458  loss_cls: 0.05679  loss_box_reg: 0.08334  loss_mask: 0.3022  loss_rpn_cls: 0.01611  loss_rpn_loc: 0.02554    time: 0.6074  last_time: 0.6365  data_time: 0.0107  last_data_time: 0.0169   lr: 0.00025  max_mem: 2801M
# [08/11 09:36:57 d2.utils.events]:  eta: 0:03:41  iter: 1139  total_loss: 0.5146  loss_cls: 0.05618  loss_box_reg: 0.07459  loss_mask: 0.2662  loss_rpn_cls: 0.01973  loss_rpn_loc: 0.01656    time: 0.6072  last_time: 0.4550  data_time: 0.0086  last_data_time: 0.0066   lr: 0.00025  max_mem: 2801M
# [08/11 09:37:09 d2.utils.events]:  eta: 0:03:29  iter: 1159  total_loss: 0.5434  loss_cls: 0.05353  loss_box_reg: 0.07868  loss_mask: 0.3122  loss_rpn_cls: 0.02108  loss_rpn_loc: 0.0283    time: 0.6072  last_time: 0.6246  data_time: 0.0141  last_data_time: 0.0174   lr: 0.00025  max_mem: 2801M
# [08/11 09:37:21 d2.utils.events]:  eta: 0:03:17  iter: 1179  total_loss: 0.6283  loss_cls: 0.07499  loss_box_reg: 0.08353  loss_mask: 0.3876  loss_rpn_cls: 0.01986  loss_rpn_loc: 0.04918    time: 0.6074  last_time: 0.6192  data_time: 0.0102  last_data_time: 0.0059   lr: 0.00025  max_mem: 2801M
# [08/11 09:37:33 d2.utils.events]:  eta: 0:03:04  iter: 1199  total_loss: 0.4627  loss_cls: 0.05044  loss_box_reg: 0.06533  loss_mask: 0.2894  loss_rpn_cls: 0.01478  loss_rpn_loc: 0.01883    time: 0.6076  last_time: 0.5892  data_time: 0.0113  last_data_time: 0.0130   lr: 0.00025  max_mem: 2801M
# [08/11 09:37:45 d2.utils.events]:  eta: 0:02:52  iter: 1219  total_loss: 0.5477  loss_cls: 0.05982  loss_box_reg: 0.07843  loss_mask: 0.359  loss_rpn_cls: 0.01391  loss_rpn_loc: 0.03721    time: 0.6072  last_time: 0.6192  data_time: 0.0083  last_data_time: 0.0060   lr: 0.00025  max_mem: 2801M
# [08/11 09:37:58 d2.utils.events]:  eta: 0:02:40  iter: 1239  total_loss: 0.5409  loss_cls: 0.04937  loss_box_reg: 0.08517  loss_mask: 0.2889  loss_rpn_cls: 0.0137  loss_rpn_loc: 0.01786    time: 0.6077  last_time: 0.6451  data_time: 0.0081  last_data_time: 0.0137   lr: 0.00025  max_mem: 2801M
# [08/11 09:38:10 d2.utils.events]:  eta: 0:02:28  iter: 1259  total_loss: 0.5433  loss_cls: 0.047  loss_box_reg: 0.06808  loss_mask: 0.3068  loss_rpn_cls: 0.01908  loss_rpn_loc: 0.02941    time: 0.6076  last_time: 0.6177  data_time: 0.0085  last_data_time: 0.0031   lr: 0.00025  max_mem: 2801M
# [08/11 09:38:23 d2.utils.events]:  eta: 0:02:16  iter: 1279  total_loss: 0.6176  loss_cls: 0.05885  loss_box_reg: 0.07658  loss_mask: 0.4229  loss_rpn_cls: 0.02278  loss_rpn_loc: 0.03276    time: 0.6079  last_time: 0.6277  data_time: 0.0123  last_data_time: 0.0126   lr: 0.00025  max_mem: 2801M
# [08/11 09:38:36 d2.utils.events]:  eta: 0:02:03  iter: 1299  total_loss: 0.552  loss_cls: 0.06025  loss_box_reg: 0.08611  loss_mask: 0.2837  loss_rpn_cls: 0.01889  loss_rpn_loc: 0.02405    time: 0.6085  last_time: 0.5468  data_time: 0.0129  last_data_time: 0.0064   lr: 0.00025  max_mem: 2801M
# [08/11 09:38:47 d2.utils.events]:  eta: 0:01:51  iter: 1319  total_loss: 0.5731  loss_cls: 0.04715  loss_box_reg: 0.05387  loss_mask: 0.3587  loss_rpn_cls: 0.02702  loss_rpn_loc: 0.05842    time: 0.6081  last_time: 0.6362  data_time: 0.0132  last_data_time: 0.0054   lr: 0.00025  max_mem: 2801M
# [08/11 09:38:59 d2.utils.events]:  eta: 0:01:39  iter: 1339  total_loss: 0.5046  loss_cls: 0.04738  loss_box_reg: 0.05064  loss_mask: 0.302  loss_rpn_cls: 0.0204  loss_rpn_loc: 0.02743    time: 0.6079  last_time: 0.5469  data_time: 0.0103  last_data_time: 0.0074   lr: 0.00025  max_mem: 2801M
# [08/11 09:39:11 d2.utils.events]:  eta: 0:01:26  iter: 1359  total_loss: 0.5214  loss_cls: 0.06937  loss_box_reg: 0.08633  loss_mask: 0.3469  loss_rpn_cls: 0.01955  loss_rpn_loc: 0.01189    time: 0.6078  last_time: 0.6025  data_time: 0.0132  last_data_time: 0.0046   lr: 0.00025  max_mem: 2801M
# [08/11 09:39:24 d2.utils.events]:  eta: 0:01:14  iter: 1379  total_loss: 0.449  loss_cls: 0.05321  loss_box_reg: 0.08319  loss_mask: 0.2319  loss_rpn_cls: 0.01543  loss_rpn_loc: 0.0167    time: 0.6081  last_time: 0.6081  data_time: 0.0112  last_data_time: 0.0043   lr: 0.00025  max_mem: 2801M
# [08/11 09:39:36 d2.utils.events]:  eta: 0:01:02  iter: 1399  total_loss: 0.5155  loss_cls: 0.06352  loss_box_reg: 0.07422  loss_mask: 0.2611  loss_rpn_cls: 0.01388  loss_rpn_loc: 0.01264    time: 0.6082  last_time: 0.6019  data_time: 0.0103  last_data_time: 0.0041   lr: 0.00025  max_mem: 2801M
# [08/11 09:39:49 d2.utils.events]:  eta: 0:00:49  iter: 1419  total_loss: 0.5128  loss_cls: 0.06647  loss_box_reg: 0.06924  loss_mask: 0.2957  loss_rpn_cls: 0.01639  loss_rpn_loc: 0.02604    time: 0.6086  last_time: 0.6151  data_time: 0.0099  last_data_time: 0.0061   lr: 0.00025  max_mem: 2801M
# [08/11 09:40:01 d2.utils.events]:  eta: 0:00:37  iter: 1439  total_loss: 0.513  loss_cls: 0.0611  loss_box_reg: 0.07883  loss_mask: 0.2604  loss_rpn_cls: 0.0164  loss_rpn_loc: 0.02831    time: 0.6087  last_time: 0.4557  data_time: 0.0092  last_data_time: 0.0068   lr: 0.00025  max_mem: 2801M
# [08/11 09:40:13 d2.utils.events]:  eta: 0:00:24  iter: 1459  total_loss: 0.5805  loss_cls: 0.04649  loss_box_reg: 0.07585  loss_mask: 0.296  loss_rpn_cls: 0.01848  loss_rpn_loc: 0.02253    time: 0.6086  last_time: 0.6977  data_time: 0.0134  last_data_time: 0.0079   lr: 0.00025  max_mem: 2801M
# [08/11 09:40:25 d2.utils.events]:  eta: 0:00:12  iter: 1479  total_loss: 0.4548  loss_cls: 0.06753  loss_box_reg: 0.07228  loss_mask: 0.2885  loss_rpn_cls: 0.0176  loss_rpn_loc: 0.04417    time: 0.6085  last_time: 0.6091  data_time: 0.0108  last_data_time: 0.0055   lr: 0.00025  max_mem: 2801M
# [08/11 09:40:40 d2.utils.events]:  eta: 0:00:00  iter: 1499  total_loss: 0.4177  loss_cls: 0.04571  loss_box_reg: 0.06039  loss_mask: 0.2723  loss_rpn_cls: 0.01878  loss_rpn_loc: 0.02004    time: 0.6084  last_time: 0.6096  data_time: 0.0092  last_data_time: 0.0041   lr: 0.00025  max_mem: 2801M
# [08/11 09:40:41 d2.engine.hooks]: Overall training speed: 1498 iterations in 0:15:11 (0.6084 s / it)
# [08/11 09:40:41 d2.engine.hooks]: Total training time: 0:15:15 (0:00:04 on hooks)
# WARNING [08/11 09:40:41 d2.data.datasets.coco]:
# Category ids in annotations are not in [1, #categories]! We'll apply a mapping for you.
#
# [08/11 09:40:41 d2.data.datasets.coco]: Loaded 183 images in COCO format from Lumet_FastAPI/dataset/valid/_annotations.coco.json
# [08/11 09:40:41 d2.data.dataset_mapper]: [DatasetMapper] Augmentations used in inference: [ResizeShortestEdge(short_edge_length=(800, 800), max_size=1333, sample_style='choice')]
# [08/11 09:40:41 d2.data.common]: Serializing the dataset using: <class 'detectron2.data.common._TorchSerializedList'>
# [08/11 09:40:41 d2.data.common]: Serializing 183 elements to byte tensors and concatenating them all ...
# [08/11 09:40:41 d2.data.common]: Serialized dataset takes 0.14 MiB
# WARNING [08/11 09:40:41 d2.engine.defaults]: No evaluator found. Use `DefaultTrainer.test(evaluators=)`, or implement its `build_evaluator` method.

# %%
#Entrenar
trainer.train()

# %%
# Ejecuta esta celda para guardar la configuración BUENA
with open("config.yaml", "w") as f:
  f.write(cfg.dump())

print("¡Listo! El archivo 'config.yaml' correcto ha sido guardado.")
# Out:
# ¡Listo! El archivo 'config.yaml' correcto ha sido guardado.

# %%
# !wget https://di-uploads-pod16.dealerinspire.com/toyotaofnorthcharlotte/uploads/2021/10/Charlotte-Toyota-service-1-1024x683.jpg -O imagen.jpg
# Out:
# --2025-08-11 09:18:43--  https://di-uploads-pod16.dealerinspire.com/toyotaofnorthcharlotte/uploads/2021/10/Charlotte-Toyota-service-1-1024x683.jpg
# Resolving di-uploads-pod16.dealerinspire.com (di-uploads-pod16.dealerinspire.com)... 18.238.238.72, 18.238.238.38, 18.238.238.59, ...
# Connecting to di-uploads-pod16.dealerinspire.com (di-uploads-pod16.dealerinspire.com)|18.238.238.72|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 37721 (37K) [image/jpeg]
# Saving to: ‘imagen.jpg’
#
# imagen.jpg          100%[===================>]  36.84K  --.-KB/s    in 0.05s
#
# 2025-08-11 09:18:44 (729 KB/s) - ‘imagen.jpg’ saved [37721/37721]

# %%
# --- SCRIPT DE VERIFICACIÓN RÁPIDA ---
from detectron2.config import get_cfg

cfg = get_cfg()
try:
    cfg.merge_from_file("config.yaml")
    num_classes = cfg.MODEL.ROI_HEADS.NUM_CLASSES
    print(f"¡Verificación exitosa!")
    print(f"--> El archivo 'config.yaml' tiene configurado un modelo con {num_classes} clases.")

    if num_classes == 9:
        print("--> ¡CORRECTO! El número de clases es 9, como debe ser. Puedes continuar.")
    else:
        print(f"--> ¡ERROR! El número de clases es {num_classes}, pero debería ser 9. Estás usando el 'config.yaml' incorrecto.")
        print("--> Por favor, asegúrate de guardar y subir el 'config.yaml' correcto de tu sesión de entrenamiento.")

except FileNotFoundError:
    print("¡ERROR! No se encontró el archivo 'config.yaml'. Asegúrate de haberlo creado y subido a Colab.")
# Out:
# ¡Verificación exitosa!
# --> El archivo 'config.yaml' tiene configurado un modelo con 9 clases.
# --> ¡CORRECTO! El número de clases es 9, como debe ser. Puedes continuar.

# %%
import os
import cv2
from google.colab.patches import cv2_imshow

# Importar las herramientas de Detectron2
from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg
from detectron2.utils.visualizer import Visualizer
from detectron2.data import MetadataCatalog

# --- 1. Cargar la Configuración y el Modelo de Forma Correcta ---
print("Cargando el modelo y la configuración desde los archivos guardados...")

cfg = get_cfg()

# Carga la configuración EXACTA desde tu archivo .yaml. Esto resuelve todos los warnings.
cfg.merge_from_file("config.yaml")

# Ahora, solo necesitas especificar los pesos y el umbral para la PREDICCIÓN.
cfg.MODEL.WEIGHTS = os.path.join("output", "model_final.pth")
cfg.MODEL.ROI_HEADS.SCORE_THRESH_TEST = 0.06 # Empecemos con un umbral razonable de 50%
cfg.MODEL.DEVICE = "cuda"

# No es necesario poner cfg.MODEL.ROI_HEADS.NUM_CLASSES = 9, porque ya está en config.yaml

# Configurar los nombres de las clases para poder ver las etiquetas
class_names = [
    "dents", "minor-dent", "minor-scratch", "moderate-broken",
    "moderate-dent", "moderate-scratch", "severe-broken", "severe-dent",
    "severe-scratch"
]
metadata = MetadataCatalog.get("lumet_inference_metadata")
metadata.set(thing_classes=class_names)

# Crear el predictor con la configuración CORRECTA Y COMPATIBLE
predictor = DefaultPredictor(cfg)
print("¡Modelo cargado correctamente!")

# --- 2. Cargar tu imagen de prueba ---
file_path = "imagen.jpg" # El nombre de la imagen que subiste
print(f"Cargando imagen: {file_path}")
im = cv2.imread(file_path)

if im is None:
    print(f"Error: No se pudo cargar la imagen. Revisa el nombre del archivo.")
else:
    # --- 3. Realizar predicción y mostrar el resultado ---
    print("\nRealizando predicción...")
    outputs = predictor(im)
    instances = outputs["instances"].to("cpu")

    num_predictions = len(instances)
    print(f"--> ¡Éxito! Se encontraron {num_predictions} imperfecciones.")

    # Dibujar las predicciones en la imagen
    v = Visualizer(im[:, :, ::-1], metadata=metadata, scale=1.0)
    out = v.draw_instance_predictions(instances)

    # Mostrar el resultado final
    cv2_imshow(out.get_image()[:, :, ::-1])
# Out:
# Cargando el modelo y la configuración desde los archivos guardados...
# [08/11 09:57:22 d2.checkpoint.detection_checkpoint]: [DetectionCheckpointer] Loading from output/model_final.pth ...
# ¡Modelo cargado correctamente!
# Cargando imagen: imagen.jpg
#
# Realizando predicción...
# --> ¡Éxito! Se encontraron 15 imperfecciones.
# <PIL.Image.Image image mode=RGB size=1024x683>
